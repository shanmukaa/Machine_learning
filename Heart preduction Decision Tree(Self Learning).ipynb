# %%
import pandas as pd

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.describe(include="O")
# Out:
#         Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# count   918           918        918            918      918
# unique    2             4          3              2        3
# top       M           ASY     Normal              N     Flat
# freq    725           496        552            547      460

# %% [markdown]
# ### Encoding

# %%
data = pd.get_dummies(df.Sex, prefix='Gender', drop_first = True)
df = pd.concat([data,df],axis = 1)
df.drop(columns='Sex',inplace = True)

# %%
df
# Out:
#      Gender_M  Age ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0        True   40           ATA        140          289          0
# 1       False   49           NAP        160          180          0
# 2        True   37           ATA        130          283          0
# 3       False   48           ASY        138          214          0
# 4        True   54           NAP        150          195          0
# ..        ...  ...           ...        ...          ...        ...
# 913      True   45            TA        110          264          0
# 914      True   68           ASY        144          193          1
# 915      True   57           ASY        130          131          0
# 916     False   57           ATA        130          236          0
# 917      True   38           NAP        138          175          0
#
#     RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0       Normal    172              N      0.0       Up             0
# 1       Normal    156              N      1.0     Flat             1
# 2           ST     98              N      0.0       Up             0
# 3       Normal    108              Y      1.5     Flat             1
# 4       Normal    122              N      0.0       Up             0
# ..         ...    ...            ...      ...      ...           ...
# 913     Normal    132              N      1.2     Flat             1
# 914     Normal    141              N      3.4     Flat             1
# 915     Normal    115              Y      1.2     Flat             1
# 916        LVH    174              N      0.0     Flat             1
# 917     Normal    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
data = pd.get_dummies(df.ChestPainType, prefix="ChestPain", drop_first=True)
df = pd.concat([data,df], axis=1)
df.drop(columns='ChestPainType', inplace=True)

# %%
df
# Out:
#      ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  RestingBP  \
# 0             True          False         False      True   40        140
# 1            False           True         False     False   49        160
# 2             True          False         False      True   37        130
# 3            False          False         False     False   48        138
# 4            False           True         False      True   54        150
# ..             ...            ...           ...       ...  ...        ...
# 913          False          False          True      True   45        110
# 914          False          False         False      True   68        144
# 915          False          False         False      True   57        130
# 916           True          False         False     False   57        130
# 917          False           True         False      True   38        138
#
#      Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak  \
# 0            289          0     Normal    172              N      0.0
# 1            180          0     Normal    156              N      1.0
# 2            283          0         ST     98              N      0.0
# 3            214          0     Normal    108              Y      1.5
# 4            195          0     Normal    122              N      0.0
# ..           ...        ...        ...    ...            ...      ...
# 913          264          0     Normal    132              N      1.2
# 914          193          1     Normal    141              N      3.4
# 915          131          0     Normal    115              Y      1.2
# 916          236          0        LVH    174              N      0.0
# 917          175          0     Normal    173              N      0.0
#
#     ST_Slope  HeartDisease
# 0         Up             0
# 1       Flat             1
# 2         Up             0
# 3       Flat             1
# 4         Up             0
# ..       ...           ...
# 913     Flat             1
# 914     Flat             1
# 915     Flat             1
# 916     Flat             1
# 917       Up             0
#
# [918 rows x 14 columns]

# %%
data = pd.get_dummies(df.RestingECG, prefix='RestingECG', drop_first=True)
df = pd.concat([data,df], axis=1)
df.drop(columns='RestingECG', inplace=True)

# %%
df
# Out:
#      RestingECG_Normal  RestingECG_ST  ChestPain_ATA  ChestPain_NAP  \
# 0                 True          False           True          False
# 1                 True          False          False           True
# 2                False           True           True          False
# 3                 True          False          False          False
# 4                 True          False          False           True
# ..                 ...            ...            ...            ...
# 913               True          False          False          False
# 914               True          False          False          False
# 915               True          False          False          False
# 916              False          False           True          False
# 917               True          False          False           True
#
#      ChestPain_TA  Gender_M  Age  RestingBP  Cholesterol  FastingBS  MaxHR  \
# 0           False      True   40        140          289          0    172
# 1           False     False   49        160          180          0    156
# 2           False      True   37        130          283          0     98
# 3           False     False   48        138          214          0    108
# 4           False      True   54        150          195          0    122
# ..            ...       ...  ...        ...          ...        ...    ...
# 913          True      True   45        110          264          0    132
# 914         False      True   68        144          193          1    141
# 915         False      True   57        130          131          0    115
# 916         False     False   57        130          236          0    174
# 917         False      True   38        138          175          0    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0                N      0.0       Up             0
# 1                N      1.0     Flat             1
# 2                N      0.0       Up             0
# 3                Y      1.5     Flat             1
# 4                N      0.0       Up             0
# ..             ...      ...      ...           ...
# 913              N      1.2     Flat             1
# 914              N      3.4     Flat             1
# 915              Y      1.2     Flat             1
# 916              N      0.0     Flat             1
# 917              N      0.0       Up             0
#
# [918 rows x 15 columns]

# %%
data = pd.get_dummies(df.ExerciseAngina, prefix='ExerciseAngina', drop_first=True)
df = pd.concat([data,df], axis=1)
df.drop(columns='ExerciseAngina', inplace=True)

# %%
df
# Out:
#      ExerciseAngina_Y  RestingECG_Normal  RestingECG_ST  ChestPain_ATA  \
# 0               False               True          False           True
# 1               False               True          False          False
# 2               False              False           True           True
# 3                True               True          False          False
# 4               False               True          False          False
# ..                ...                ...            ...            ...
# 913             False               True          False          False
# 914             False               True          False          False
# 915              True               True          False          False
# 916             False              False          False           True
# 917             False               True          False          False
#
#      ChestPain_NAP  ChestPain_TA  Gender_M  Age  RestingBP  Cholesterol  \
# 0            False         False      True   40        140          289
# 1             True         False     False   49        160          180
# 2            False         False      True   37        130          283
# 3            False         False     False   48        138          214
# 4             True         False      True   54        150          195
# ..             ...           ...       ...  ...        ...          ...
# 913          False          True      True   45        110          264
# 914          False         False      True   68        144          193
# 915          False         False      True   57        130          131
# 916          False         False     False   57        130          236
# 917           True         False      True   38        138          175
#
#      FastingBS  MaxHR  Oldpeak ST_Slope  HeartDisease
# 0            0    172      0.0       Up             0
# 1            0    156      1.0     Flat             1
# 2            0     98      0.0       Up             0
# 3            0    108      1.5     Flat             1
# 4            0    122      0.0       Up             0
# ..         ...    ...      ...      ...           ...
# 913          0    132      1.2     Flat             1
# 914          1    141      3.4     Flat             1
# 915          0    115      1.2     Flat             1
# 916          0    174      0.0     Flat             1
# 917          0    173      0.0       Up             0
#
# [918 rows x 15 columns]

# %%
data = pd.get_dummies(df.ST_Slope, prefix='ST_Slope', drop_first=True)
df = pd.concat([data,df], axis=1)
df.drop(columns='ST_Slope', inplace=True)

# %%
df
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [918 rows x 16 columns]

# %% [markdown]
# ### Outliers Handling

# %%
from scipy import stats
import numpy as np

# %%
l = ['Age','RestingBP','Cholesterol','FastingBS','MaxHR','Oldpeak']
for i in l:
    print(i)
    print()
    IQR = stats.iqr(df[i])
    Q1 = np.percentile(df[i], 25)
    Q3 = np.percentile(df[i], 75)
    print(Q1)
    print(Q3)
    LB = Q1 - 1.5*(IQR)
    UB = Q3 + 1.5*(IQR)
    print(LB)
    print(UB)
    print(df[(df[i]>LB) & (df[i]<UB)])
    print()
    print("Beyond Upper bound:")
    print(df.loc[df[i]>UB,i])
    print()
    print("Below Lower bound:")
    print(df.loc[df[i]<LB,i])
    print()
# Out:
# Age
#
# 47.0
# 60.0
# 27.5
# 79.5
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [918 rows x 16 columns]
#
# Beyond Upper bound:
# Series([], Name: Age, dtype: int64)
#
# Below Lower bound:
# Series([], Name: Age, dtype: int64)
#
# RestingBP
#
# 120.0
# 140.0
# 90.0
# 170.0
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [876 rows x 16 columns]
#
# Beyond Upper bound:
# 109    190
# 123    180
# 189    180
# 190    180
# 241    200
# 274    180
# 275    180
# 278    180
# 365    200
# 372    185
# 399    200
# 411    180
# 423    180
# 475    178
# 550    172
# 585    180
# 592    190
# 673    174
# 702    178
# 725    180
# 732    200
# 759    192
# 774    178
# 780    180
# 855    180
# 880    172
# Name: RestingBP, dtype: int64
#
# Below Lower bound:
# 314    80
# 449     0
# Name: RestingBP, dtype: int64
#
# Cholesterol
#
# 173.25
# 267.0
# 32.625
# 407.625
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [735 rows x 16 columns]
#
# Beyond Upper bound:
# 28     468
# 30     518
# 69     412
# 76     529
# 103    466
# 149    603
# 250    491
# 496    458
# 616    564
# 667    417
# 796    409
# Name: Cholesterol, dtype: int64
#
# Below Lower bound:
# 293    0
# 294    0
# 295    0
# 296    0
# 297    0
#       ..
# 514    0
# 515    0
# 518    0
# 535    0
# 536    0
# Name: Cholesterol, Length: 172, dtype: int64
#
# FastingBS
#
# 0.0
# 0.0
# 0.0
# 0.0
# Empty DataFrame
# Columns: [ST_Slope_Flat, ST_Slope_Up, ExerciseAngina_Y, RestingECG_Normal, RestingECG_ST, ChestPain_ATA, ChestPain_NAP, ChestPain_TA, Gender_M, Age, RestingBP, Cholesterol, FastingBS, MaxHR, Oldpeak, HeartDisease]
# Index: []
#
# Beyond Upper bound:
# 36     1
# 38     1
# 52     1
# 84     1
# 86     1
#       ..
# 887    1
# 888    1
# 901    1
# 911    1
# 914    1
# Name: FastingBS, Length: 214, dtype: int64
#
# Below Lower bound:
# Series([], Name: FastingBS, dtype: int64)
#
# MaxHR
#
# 120.0
# 156.0
# 66.0
# 210.0
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [916 rows x 16 columns]
#
# Beyond Upper bound:
# Series([], Name: MaxHR, dtype: int64)
#
# Below Lower bound:
# 370    63
# 390    60
# Name: MaxHR, dtype: int64
#
# Oldpeak
#
# 0.0
# 1.5
# -2.25
# 3.75
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [902 rows x 16 columns]
#
# Beyond Upper bound:
# 68     4.0
# 166    5.0
# 500    4.0
# 521    4.0
# 537    4.0
# 559    4.0
# 624    4.0
# 702    4.2
# 732    4.0
# 771    5.6
# 775    3.8
# 791    4.2
# 850    6.2
# 900    4.4
# 908    4.0
# Name: Oldpeak, dtype: float64
#
# Below Lower bound:
# 324   -2.6
# Name: Oldpeak, dtype: float64

# %% [markdown]
# ##### Age

# %%
stats.iqr(df.Age)
# Out:
# 13.0

# %%
IQR_Age = stats.iqr(df.Age)

# %%
import numpy as np

# %%
Q1_Age = np.percentile(df.Age, 25)
Q3_Age = np.percentile(df.Age, 75)
print(Q1_Age)
print(Q3_Age)
# Out:
# 47.0
# 60.0

# %%
Q1_Age - 1.5*(IQR_Age)
# Out:
# 27.5

# %%
Q3_Age + 1.5*(IQR_Age)
# Out:
# 79.5

# %%
LB_Age = Q1_Age - 1.5*(IQR_Age)
UB_Age = Q3_Age + 1.5*(IQR_Age)

# %%
df[(df.Age>LB_Age) & (df.Age<UB_Age)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [918 rows x 16 columns]

# %%
df.loc[df.Age>UB_Age,'Age']
# Out:
# Series([], Name: Age, dtype: int64)

# %%
df.loc[df.Age<LB_Age,'Age']
# Out:
# Series([], Name: Age, dtype: int64)

# %% [raw]
# So there are no null values in Age Column

# %% [markdown]
# ##### RestingBP

# %%
stats.iqr(df.RestingBP)
# Out:
# 20.0

# %%
IQR_RestingBP = stats.iqr(df.RestingBP)

# %%
Q1_RestingBP = np.percentile(df.RestingBP, 25)
Q3_RestingBP = np.percentile(df.RestingBP, 75)
print(Q1_RestingBP)
print(Q3_RestingBP)
# Out:
# 120.0
# 140.0

# %%
LB_RestingBP = Q1_RestingBP - 1.5*(IQR_RestingBP)
UB_RestingBP = Q3_RestingBP + 1.5*(IQR_RestingBP)
print(LB_RestingBP)
print(UB_RestingBP)
# Out:
# 90.0
# 170.0

# %%
df[(df.RestingBP>LB_RestingBP) & (df.RestingBP<UB_RestingBP)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [876 rows x 16 columns]

# %%
df.loc[df.RestingBP>UB_RestingBP,'RestingBP']
# Out:
# 109    190
# 123    180
# 189    180
# 190    180
# 241    200
# 274    180
# 275    180
# 278    180
# 365    200
# 372    185
# 399    200
# 411    180
# 423    180
# 475    178
# 550    172
# 585    180
# 592    190
# 673    174
# 702    178
# 725    180
# 732    200
# 759    192
# 774    178
# 780    180
# 855    180
# 880    172
# Name: RestingBP, dtype: int64

# %%
df.loc[df.RestingBP<LB_RestingBP,'RestingBP']
# Out:
# 314    80
# 449     0
# Name: RestingBP, dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(x = df.RestingBP)
# Out:
# <Axes: xlabel='RestingBP'>

# %%
((918-876)/918)*100
# Out:
# 4.57516339869281

# %% [raw]
# As the outliers percentage is less than 5%. So we are handling it

# %%
df.RestingBP.median()
# Out:
# 130.0

# %%
df.loc[df.RestingBP > UB_RestingBP, 'RestingBP'] = 130

# %%
df.loc[df.RestingBP < LB_RestingBP, 'RestingBP'] = 130

# %%
df.loc[df.RestingBP > UB_RestingBP, 'RestingBP']
# Out:
# Series([], Name: RestingBP, dtype: int64)

# %%
df.loc[df.RestingBP < LB_RestingBP, 'RestingBP']
# Out:
# Series([], Name: RestingBP, dtype: int64)

# %%
sns.boxenplot(x = df.RestingBP)
# Out:
# <Axes: xlabel='RestingBP'>

# %% [markdown]
# ##### Cholesterol

# %%
stats.iqr(df.Cholesterol)
# Out:
# 93.75

# %%
IQR_Cholesterol = stats.iqr(df.Cholesterol)

# %%
Q1_Cholesterol = np.percentile(df.Cholesterol, 25)
Q3_Cholesterol = np.percentile(df.Cholesterol, 75)
print(Q1_Cholesterol)
print(Q3_Cholesterol)
# Out:
# 173.25
# 267.0

# %%
LB_Cholesterol = Q1_Cholesterol - 1.5*(IQR_Cholesterol)
UB_Cholesterol = Q3_Cholesterol + 1.5*(IQR_Cholesterol)
print(LB_Cholesterol)
print(UB_Cholesterol)
# Out:
# 32.625
# 407.625

# %%
df[(df.Cholesterol>LB_Cholesterol) & (df.Cholesterol<UB_Cholesterol)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [735 rows x 16 columns]

# %%
((918-735)/918)*100
# Out:
# 19.934640522875817

# %% [raw]
# As the outliers are of 19% (>5%), we wont handle then as they can mislead the data

# %% [markdown]
# ##### FastingBS

# %%
stats.iqr(df.FastingBS)
# Out:
# 0.0

# %% [raw]
# As IQR value is 0. No need to handle the outliers

# %% [markdown]
# ##### MaxHR

# %%
stats.iqr(df.MaxHR)
# Out:
# 36.0

# %%
IQR_MaxHR = stats.iqr(df.MaxHR)

# %%
Q1_MaxHR = np.percentile(df.MaxHR, 25)
Q3_MaxHR = np.percentile(df.MaxHR, 75)
print(Q1_MaxHR)
print(Q3_MaxHR)
# Out:
# 120.0
# 156.0

# %%
LB_MaxHR = Q1_MaxHR - 1.5*(IQR_MaxHR)
UB_MaxHR = Q3_MaxHR + 1.5*(IQR_MaxHR)
print(LB_MaxHR)
print(UB_MaxHR)
# Out:
# 66.0
# 210.0

# %%
df[(df.MaxHR>LB_MaxHR) & (df.MaxHR<UB_MaxHR)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [916 rows x 16 columns]

# %%
(2/918)*100
# Out:
# 0.2178649237472767

# %% [raw]
# As the outliers percentage is less than 5%. So we are handling it

# %%
sns.boxplot(df.MaxHR)
# Out:
# <Axes: ylabel='MaxHR'>

# %%
df.MaxHR.median()
# Out:
# 138.0

# %%
df.loc[df.MaxHR > UB_MaxHR, 'MaxHR'] = 138

# %%
df.loc[df.MaxHR < LB_MaxHR, 'MaxHR'] = 138

# %%
df.loc[df.MaxHR > UB_MaxHR, 'MaxHR']
# Out:
# Series([], Name: MaxHR, dtype: int64)

# %%
df.loc[df.MaxHR < LB_MaxHR, 'MaxHR']
# Out:
# Series([], Name: MaxHR, dtype: int64)

# %%
sns.boxplot(df.MaxHR)
# Out:
# <Axes: ylabel='MaxHR'>

# %% [markdown]
# ##### Oldpeak

# %%
stats.iqr(df.Oldpeak)
# Out:
# 1.5

# %%
IQR_Oldpeak = stats.iqr(df.Oldpeak)

# %%
Q1_Oldpeak = np.percentile(df.Oldpeak, 25)
Q3_Oldpeak = np.percentile(df.Oldpeak, 75)
print(Q1_Oldpeak)
print(Q3_Oldpeak)
# Out:
# 0.0
# 1.5

# %%
LB_Oldpeak = Q1_Oldpeak - 1.5*(IQR_Oldpeak)
UB_Oldpeak = Q3_Oldpeak + 1.5*(IQR_Oldpeak)
print(LB_Oldpeak)
print(UB_Oldpeak)
# Out:
# -2.25
# 3.75

# %%
df[(df.Oldpeak>LB_Oldpeak) & (df.Oldpeak<UB_Oldpeak)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [902 rows x 16 columns]

# %%
((918-902)/918)*100
# Out:
# 1.7429193899782136

# %% [raw]
# As the outliers percentage is less than 5%. So we are handling it

# %%
sns.boxplot(df.Oldpeak)
# Out:
# <Axes: ylabel='Oldpeak'>

# %%
df.Oldpeak.median()
# Out:
# 0.6

# %%
df.loc[df.Oldpeak > UB_Oldpeak, 'Oldpeak'] = 0.6

# %%
df.loc[df.Oldpeak < LB_Oldpeak, 'Oldpeak'] = 0.6

# %%
df.loc[df.Oldpeak > UB_Oldpeak, 'Oldpeak']
# Out:
# Series([], Name: Oldpeak, dtype: float64)

# %%
df.loc[df.Oldpeak < LB_Oldpeak, 'Oldpeak']
# Out:
# Series([], Name: Oldpeak, dtype: float64)

# %%
sns.boxplot(df.Oldpeak)
# Out:
# <Axes: ylabel='Oldpeak'>

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()
df[['Age','RestingBP','Cholesterol','MaxHR']]=scale.fit_transform(df[['Age','RestingBP','Cholesterol','MaxHR']])

# %%
df
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  \
# 0            False           True          False         False      True
# 1            False          False           True         False     False
# 2             True           True          False         False      True
# 3            False          False          False         False     False
# 4            False          False           True         False      True
# ..             ...            ...            ...           ...       ...
# 913          False          False          False          True      True
# 914          False          False          False         False      True
# 915          False          False          False         False      True
# 916          False           True          False         False     False
# 917          False          False           True         False      True
#
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR  Oldpeak  \
# 0    0.244898   0.615385     0.479270          0  0.777778      0.0
# 1    0.428571   0.871795     0.298507          0  0.659259      1.0
# 2    0.183673   0.487179     0.469320          0  0.229630      0.0
# 3    0.408163   0.589744     0.354892          0  0.303704      1.5
# 4    0.530612   0.743590     0.323383          0  0.407407      0.0
# ..        ...        ...          ...        ...       ...      ...
# 913  0.346939   0.230769     0.437811          0  0.481481      1.2
# 914  0.816327   0.666667     0.320066          1  0.548148      3.4
# 915  0.591837   0.487179     0.217247          0  0.355556      1.2
# 916  0.591837   0.487179     0.391376          0  0.792593      0.0
# 917  0.204082   0.589744     0.290216          0  0.785185      0.0
#
#      HeartDisease
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0
# ..            ...
# 913             1
# 914             1
# 915             1
# 916             1
# 917             0
#
# [918 rows x 16 columns]

# %%
# Target and predictio separation
X = df.iloc[:,:-1]
y = df.HeartDisease

# %%
X
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  \
# 0            False           True          False         False      True
# 1            False          False           True         False     False
# 2             True           True          False         False      True
# 3            False          False          False         False     False
# 4            False          False           True         False      True
# ..             ...            ...            ...           ...       ...
# 913          False          False          False          True      True
# 914          False          False          False         False      True
# 915          False          False          False         False      True
# 916          False           True          False         False     False
# 917          False          False           True         False      True
#
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR  Oldpeak
# 0    0.244898   0.615385     0.479270          0  0.777778      0.0
# 1    0.428571   0.871795     0.298507          0  0.659259      1.0
# 2    0.183673   0.487179     0.469320          0  0.229630      0.0
# 3    0.408163   0.589744     0.354892          0  0.303704      1.5
# 4    0.530612   0.743590     0.323383          0  0.407407      0.0
# ..        ...        ...          ...        ...       ...      ...
# 913  0.346939   0.230769     0.437811          0  0.481481      1.2
# 914  0.816327   0.666667     0.320066          1  0.548148      3.4
# 915  0.591837   0.487179     0.217247          0  0.355556      1.2
# 916  0.591837   0.487179     0.391376          0  0.792593      0.0
# 917  0.204082   0.589744     0.290216          0  0.785185      0.0
#
# [918 rows x 15 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
#Train Test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=3)

# %% [markdown]
# ### Model Creation

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import accuracy_score, classification_report
y_pred = model.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.842391304347826

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83        87
#            1       0.85      0.86      0.85        97
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.84      0.84      0.84       184

# %%
# Tree structure
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.5113735465116279, 0.9736842105263158, 'x[1] <= 0.5\ngini = 0.493\nsamples = 734\nvalue = [324, 410]'),
#  Text(0.2640261627906977, 0.9210526315789473, 'x[8] <= 0.5\ngini = 0.299\nsamples = 421\nvalue = [77, 344]'),
#  Text(0.3876998546511628, 0.9473684210526316, 'True  '),
#  Text(0.1, 0.868421052631579, 'x[12] <= 0.5\ngini = 0.5\nsamples = 64\nvalue = [32, 32]'),
#  Text(0.09069767441860466, 0.8157894736842105, 'x[2] <= 0.5\ngini = 0.492\nsamples = 57\nvalue = [32, 25]'),
#  Text(0.046511627906976744, 0.7631578947368421, 'x[10] <= 0.718\ngini = 0.397\nsamples = 33\nvalue = [24, 9]'),
#  Text(0.027906976744186046, 0.7105263157894737, 'x[14] <= 2.8\ngini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(0.018604651162790697, 0.6578947368421053, 'x[9] <= 0.214\ngini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.009302325581395349, 0.6052631578947368, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.027906976744186046, 0.6052631578947368, 'x[13] <= 0.226\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.018604651162790697, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.037209302325581395, 0.5526315789473685, 'x[13] <= 0.789\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(0.027906976744186046, 0.5, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.046511627906976744, 0.5, 'x[9] <= 0.469\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.037209302325581395, 0.4473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05581395348837209, 0.4473684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.037209302325581395, 0.6578947368421053, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06511627906976744, 0.7105263157894737, 'x[9] <= 0.765\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.05581395348837209, 0.6578947368421053, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.07441860465116279, 0.6578947368421053, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13488372093023257, 0.7631578947368421, 'x[9] <= 0.52\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.11162790697674418, 0.7105263157894737, 'x[11] <= 0.405\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.09302325581395349, 0.6578947368421053, 'x[13] <= 0.385\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.08372093023255814, 0.6052631578947368, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10232558139534884, 0.6052631578947368, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.13023255813953488, 0.6578947368421053, 'x[11] <= 0.525\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.12093023255813953, 0.6052631578947368, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.13953488372093023, 0.6052631578947368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15813953488372093, 0.7105263157894737, 'x[4] <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.14883720930232558, 0.6578947368421053, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.16744186046511628, 0.6578947368421053, 'x[9] <= 0.571\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.15813953488372093, 0.6052631578947368, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17674418604651163, 0.6052631578947368, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10930232558139535, 0.8157894736842105, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.42805232558139533, 0.868421052631579, 'x[13] <= 0.544\ngini = 0.22\nsamples = 357\nvalue = [45, 312]'),
#  Text(0.3142441860465116, 0.8157894736842105, 'x[13] <= 0.019\ngini = 0.128\nsamples = 261\nvalue = [18, 243]'),
#  Text(0.26627906976744187, 0.7631578947368421, 'x[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2569767441860465, 0.7105263157894737, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2755813953488372, 0.7105263157894737, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3622093023255814, 0.7631578947368421, 'x[10] <= 0.494\ngini = 0.123\nsamples = 259\nvalue = [17, 242]'),
#  Text(0.2941860465116279, 0.7105263157894737, 'x[4] <= 0.5\ngini = 0.177\nsamples = 122\nvalue = [12, 110]'),
#  Text(0.23953488372093024, 0.6578947368421053, 'x[9] <= 0.724\ngini = 0.101\nsamples = 94\nvalue = [5, 89]'),
#  Text(0.19534883720930232, 0.6052631578947368, 'x[13] <= 0.433\ngini = 0.067\nsamples = 86\nvalue = [3, 83]'),
#  Text(0.16279069767441862, 0.5526315789473685, 'x[6] <= 0.5\ngini = 0.032\nsamples = 61\nvalue = [1, 60]'),
#  Text(0.15348837209302327, 0.5, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]'),
#  Text
 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8976744186046511, 0.5526315789473685, 'x[11] <= 0.503\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.8883720930232558, 0.5, 'x[11] <= 0.391\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.8790697674418605, 0.4473684210526316, 'x[10] <= 0.667\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8697674418604651, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8883720930232558, 0.39473684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8976744186046511, 0.4473684210526316, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9069767441860465, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9255813953488372, 0.6052631578947368, 'x[11] <= 0.541\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.9162790697674419, 0.5526315789473685, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.9348837209302325, 0.5526315789473685, 'x[8] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9255813953488372, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9441860465116279, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8813953488372093, 0.7105263157894737, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9813953488372092, 0.8157894736842105, 'x[13] <= 0.707\ngini = 0.496\nsamples = 33\nvalue = [18, 15]'),
#  Text(0.9720930232558139, 0.7631578947368421, 'x[6] <= 0.5\ngini = 0.48\nsamples = 25\nvalue = [10, 15]'),
#  Text(0.9627906976744186, 0.7105263157894737, 'x[13] <= 0.556\ngini = 0.375\nsamples = 20\nvalue = [5, 15]'),
#  Text(0.9534883720930233, 0.6578947368421053, 'x[14] <= 0.05\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.9441860465116279, 0.6052631578947368, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9627906976744186, 0.6052631578947368, 'x[7] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.9534883720930233, 0.5526315789473685, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9720930232558139, 0.5526315789473685, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9720930232558139, 0.6578947368421053, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9813953488372092, 0.7105263157894737, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9906976744186047, 0.7631578947368421, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]')]

# %%
y_pred_train = model.predict(X_train)
accuracy_score(y_pred_train, y_train)
# Out:
# 1.0

# %%
model = DecisionTreeClassifier(max_depth = 4)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
y_pred = model.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.875

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86        79
#            1       0.92      0.86      0.89       105
#
#     accuracy                           0.88       184
#    macro avg       0.87      0.88      0.87       184
# weighted avg       0.88      0.88      0.88       184

# %%
tree.plot_tree(model)
# Out:
# [Text(0.4791666666666667, 0.9, 'x[1] <= 0.5\ngini = 0.493\nsamples = 734\nvalue = [324, 410]'),
#  Text(0.22916666666666666, 0.7, 'x[8] <= 0.5\ngini = 0.299\nsamples = 421\nvalue = [77, 344]'),
#  Text(0.3541666666666667, 0.8, 'True  '),
#  Text(0.125, 0.5, 'x[12] <= 0.5\ngini = 0.5\nsamples = 64\nvalue = [32, 32]'),
#  Text(0.08333333333333333, 0.3, 'x[2] <= 0.5\ngini = 0.492\nsamples = 57\nvalue = [32, 25]'),
#  Text(0.041666666666666664, 0.1, 'gini = 0.397\nsamples = 33\nvalue = [24, 9]'),
#  Text(0.125, 0.1, 'gini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.16666666666666666, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.3333333333333333, 0.5, 'x[13] <= 0.544\ngini = 0.22\nsamples = 357\nvalue = [45, 312]'),
#  Text(0.25, 0.3, 'x[13] <= 0.019\ngini = 0.128\nsamples = 261\nvalue = [18, 243]'),
#  Text(0.20833333333333334, 0.1, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2916666666666667, 0.1, 'gini = 0.123\nsamples = 259\nvalue = [17, 242]'),
#  Text(0.4166666666666667, 0.3, 'x[13] <= 0.881\ngini = 0.404\nsamples = 96\nvalue = [27, 69]'),
#  Text(0.375, 0.1, 'gini = 0.39\nsamples = 94\nvalue = [25, 69]'),
#  Text(0.4583333333333333, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7291666666666666, 0.7, 'x[11] <= 0.07\ngini = 0.333\nsamples = 313\nvalue = [247, 66]'),
#  Text(0.6041666666666666, 0.8, '  False'),
#  Text(0.625, 0.5, 'x[12] <= 0.5\ngini = 0.427\nsamples = 42\nvalue = [13, 29]'),
#  Text(0.5833333333333334, 0.3, 'x[13] <= 0.263\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.5416666666666666, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.625, 0.1, 'gini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.8333333333333334, 0.5, 'x[2] <= 0.5\ngini = 0.236\nsamples = 271\nvalue = [234, 37]'),
#  Text(0.75, 0.3, 'x[9] <= 0.582\ngini = 0.168\nsamples = 238\nvalue = [216, 22]'),
#  Text(0.7083333333333334, 0.1, 'gini = 0.083\nsamples = 185\nvalue = [177, 8]'),
#  Text(0.7916666666666666, 0.1, 'gini = 0.389\nsamples = 53\nvalue = [39, 14]'),
#  Text(0.9166666666666666, 0.3, 'x[13] <= 0.707\ngini = 0.496\nsamples = 33\nvalue = [18, 15]'),
#  Text(0.875, 0.1, 'gini = 0.48\nsamples = 25\nvalue = [10, 15]'),
#  Text(0.9583333333333334, 0.1, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]')]

# %%
y_pred_train = model.predict(X_train)
accuracy_score(y_pred_train, y_train)
# Out:
# 0.8664850136239782

# %% [markdown]
# ### Feature Selection

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
imp = model.feature_importances_
indices = np.argsort(imp)
features = X_train.columns

# %%
plt.figure(figsize=(10,15))
plt.title('Feature Importance')
plt.barh(range(len(indices)), imp[indices], align='center', color='Green')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ### Hyperparameter Tuning

# %%
params = {'max_depth':[3,5,9,10,15],
          'criterion':['gini','entropy']}

# %%
# Hyper parameter tuning
from sklearn.model_selection import RandomizedSearchCV
rscv = RandomizedSearchCV(model, param_distributions = params)
rscv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(estimator=DecisionTreeClassifier(max_depth=4),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 9, 10, 15]})

# %%
rscv.best_params_
# Out:
# {'max_depth': 3, 'criterion': 'entropy'}

# %%
rscv.best_score_
# Out:
# 0.8324200913242009

# %%
from sklearn.model_selection import GridSearchCV
gscv = GridSearchCV(model, param_grid=params)
gscv.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(max_depth=4),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 9, 10, 15]})

# %%
gscv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 3}

# %%
gscv.best_score_
# Out:
# 0.8324200913242009

# %%
model = DecisionTreeClassifier(max_depth = 4 , criterion = 'entropy')
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_pred = model.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.875

# %%
y_pred_train = model.predict(X_train)
accuracy_score(y_pred_train, y_train)
# Out:
# 0.8637602179836512

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        83
#            1       0.90      0.87      0.88       101
#
#     accuracy                           0.88       184
#    macro avg       0.87      0.88      0.87       184
# weighted avg       0.88      0.88      0.88       184

# %%
import joblib

# %%
# Save model
joblib.dump(model,"decision_tree_model.pkl")
# Out:
# ['decision_tree_model.pkl']

# %% [markdown]
# ### Gradio Interface

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.31.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.10.1 (from gradio)
#   Downloading gradio_client-1.10.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub>=0.28.1 (from gradio)
#   Downloading huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.18-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (2.8.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.11.12-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.47.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in c:\users\lenovo\anaconda3\lib\site-packages (from gradio-client==1.10.1->gradio) (2024.6.1)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.10.1->gradio)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Downloading gradio-5.31.0-py3-none-any.whl (54.2 MB)
#    ---------------------------------------- 0.0/54.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/54.2 MB ? eta -:--:--
#    ---------------------------------------- 0.5/54.2 MB 1.3 MB/s eta 0:00:42
#    ---------------------------------------- 0.5/54.2 MB 1.3 MB/s eta 0:00:42
#     --------------------------------------- 0.8/54.2 MB 1.1 MB/s eta 0:00:48
#     --------------------------------------- 1.3/54.2 MB 1.3 MB/s eta 0:00:42
#    - -------------------------------------- 1.6/54.2 MB 1.3 MB/s eta 0:00:42
#    - -------------------------------------- 1.8/54.2 MB 1.3 MB/s eta 0:00:41
#    - -------------------------------------- 2.1/54.2 MB 1.3 MB/s eta 0:00:40
0 kB/s eta 0:00:04
#    ----------------------------------- ---- 10.2/11.5 MB 420.0 kB/s eta 0:00:04
#    ------------------------------------ --- 10.5/11.5 MB 416.2 kB/s eta 0:00:03
#    ------------------------------------ --- 10.5/11.5 MB 416.2 kB/s eta 0:00:03
#    ------------------------------------ --- 10.5/11.5 MB 416.2 kB/s eta 0:00:03
#    ------------------------------------- -- 10.7/11.5 MB 413.8 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.5 MB 413.8 kB/s eta 0:00:02
#    ------------------------------------- -- 10.7/11.5 MB 413.8 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 415.4 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 415.4 kB/s eta 0:00:02
#    -------------------------------------- - 11.0/11.5 MB 415.4 kB/s eta 0:00:02
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 413.0 kB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 352.7 kB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Installing collected packages: pydub, websockets, tomlkit, semantic-version, ruff, python-multipart, orjson, groovy, ffmpy, aiofiles, uvicorn, starlette, huggingface-hub, typer, safehttpx, gradio-client, fastapi, gradio
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
# Successfully installed aiofiles-24.1.0 fastapi-0.115.12 ffmpy-0.5.0 gradio-5.31.0 gradio-client-1.10.1 groovy-0.1.2 huggingface-hub-0.32.3 orjson-3.10.18 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.12 safehttpx-0.1.6 semantic-version-2.10.0 starlette-0.46.2 tomlkit-0.13.2 typer-0.16.0 uvicorn-0.34.2 websockets-15.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.5.1 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.2.0 which is incompatible.

# %%
import gradio as gr
import numpy as np

def predict_heart_disease(Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, 
                          RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope):
    # Manual dummy variable encoding (match your model training)
    
    # Binary encodings
    Sex_M = 1 if Sex == "M" else 0
    FastingBS_val = int(FastingBS)  # already 0 or 1
    ExerciseAngina_Y = 1 if ExerciseAngina == "Y" else 0

    # ChestPainType (4 types → 3 dummy vars assuming one dropped or 4 if not)
    ChestPain_ASY = 1 if ChestPainType == "ASY" else 0
    ChestPain_ATA = 1 if ChestPainType == "ATA" else 0
    ChestPain_NAP = 1 if ChestPainType == "NAP" else 0
    ChestPain_TA = 1 if ChestPainType == "TA" else 0  # Only include if used in model

    # RestingECG
    RestingECG_ST = 1 if RestingECG == "ST" else 0
    RestingECG_LVH = 1 if RestingECG == "LVH" else 0

    # ST_Slope
    ST_Slope_Flat = 1 if ST_Slope == "Flat" else 0
    ST_Slope_Up = 1 if ST_Slope == "Up" else 0

    # Form the input in model's expected order (15 features)
    input_data = np.array([[Age, Sex_M, ChestPain_ASY, ChestPain_ATA, ChestPain_NAP,
                            RestingBP, Cholesterol, FastingBS_val, RestingECG_ST, RestingECG_LVH,
                            MaxHR, ExerciseAngina_Y, Oldpeak, ST_Slope_Flat, ST_Slope_Up]])
    
    prediction = model.predict(input_data)
    return "At Risk" if prediction[0] == 1 else "Not at Risk"

# Gradio UI
iface = gr.Interface(
    fn=predict_heart_disease,
    inputs=[
        gr.Number(label="Age"),
        gr.Dropdown(["M", "F"], label="Sex"),
        gr.Dropdown(["ASY", "ATA", "NAP", "TA"], label="Chest Pain Type"),
        gr.Number(label="Resting Blood Pressure"),
        gr.Number(label="Cholesterol"),
        gr.Dropdown(["0", "1"], label="Fasting Blood Sugar > 120 mg/dl"),
        gr.Dropdown(["Normal", "ST", "LVH"], label="Resting ECG"),
        gr.Number(label="Maximum Heart Rate"),
        gr.Dropdown(["Y", "N"], label="Exercise-Induced Angina"),
        gr.Number(label="Oldpeak"),
        gr.Dropdown(["Up", "Flat", "Down"], label="ST Slope")
    ],
    outputs="text",
    title="Heart Disease Risk Predictor",
    description="Enter the values to predict the risk of heart disease."
)

iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
